# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,5,11)
y=X**2

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'y')

# %%
plt.plot(x,y,'bx')

# %%
plt.plot(x,y,'bo')

# %%
plt.plot(x,y,'rs-')

# %%
plt.plot(x,y,'bx-')

# %%
plt.plot(x,y,'yD-')

# %%
plt.hist(x)
plt.show()

# %%
plt.pie(x)
plt.show()

# %%
plt.scatter(x,y)
plt.show()

# %%
plt.boxplot(x)
plt.show()
